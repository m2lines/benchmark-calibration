# %%
import sys
sys.path.append('../src/')

from inverse_problems import min_quadratic_function, transcendental_function
from history_matching import HistoryMatching

import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 3

# %%
# We know the answer exactly
n = 5
problem = transcendental_function(n=n)

# %%
    HM = HistoryMatching(inverse_problem=problem)

# %%
for i in range(100):
    HM.iteration()

# %%
HM.plot_landscape()

# %%
plt.plot(HM.forward_evaluations, HM.error_forward, label='Best match', color='k', ls='--')
#plt.plot(HM.forward_evaluations, HM.error_new, label='Exploration')
#plt.plot(HM.forward_evaluations, HM.error_gp, label='Emulator')
#plt.plot(HM.forward_evaluations, HM.error_IF, label='Minimum Implausibility')
plt.xlim([0,None])
plt.ylabel('Error in solution of inverse problem\n$||u-u_{true}||_2$')
plt.xlabel('Number of evaluations of forward model')
plt.legend()
plt.grid()
